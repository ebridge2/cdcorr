# %%
import seaborn as sns
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels
import matplotlib.pyplot as plt
import dodiscover as dod
import hyppo
import scipy as sp
import sklearn as sk
from sims import *
import dask
from dask.distributed import Client, progress
import dask.dataframe as ddf
import logging
import warnings
warnings.filterwarnings("ignore")
import contextlib

# %% [markdown]
# # Simulations

# %%
# docker run -ti --entrypoint /bin/bash -v /cis/home/ebridge2/Documents/research/hypo-repos/cdcorr:/cdcorr neurodata/cdcorr:0.0.1
# cd cdcorr/cdcorr/simulations

import seaborn as sns
import pandas as pd
import numpy as np
import scipy as sp
import statsmodels.api as sm
import statsmodels
import matplotlib.pyplot as plt
import dodiscover as dod
import hyppo
from scipy.stats import special_ortho_group
import sklearn as sk
from sims import *
import dask
from dask.distributed import Client, progress
import dask.dataframe as ddf
import logging
import warnings
warnings.filterwarnings("ignore")
import contextlib

nbreaks = 10
nsamp = 100
plow = 10
phigh = 101
bhigh = 0.8
blow = 0.4
K = 3
nsims = 200
ncores = 50
Nrep = 1000
covar_sz = 1

def run_row(row, nrep=Nrep):
    if row["index"] % 100 == 0:
        print("Row {:d}...".format(row["index"]))
    fns_to_run = {"cMANOVA": cond_manova, "KernelCDTest" : codite, "cDCorr" : cond_dcorr, "DCorr" : dcorr}
    sim_fn = simulations[row["Setting"]]
    pvals = []
    stat_names = []
    
    if row["Setting"] == "K-Class" or row["Setting"] == "Sigmoidal":
        covar_sz = 5
    elif row["Setting"] == "Function":
        covar_sz = 5
    elif row["Setting"] == "Heteroskedastic":
        covar_sz = 3
    else:
        covar_sz = 1

    if row["Setting"] == "K-Class":
        Y, T, X, _, _, _ = sim_fn(row["#Samples"], row["Dimensionality"],
                                  causal_effect_size=row["Effect Size"], covar_effect_size=covar_sz,
                                  balance=row["Balance"],
                                  K=3)
    else:
        Y, T, X, _, _, _ = sim_fn(row["#Samples"], row["Dimensionality"],
                                  causal_effect_size=row["Effect Size"], covar_effect_size=covar_sz,
                                  balance=row["Balance"])
    # randomly rotate in D dimensions
    R = special_ortho_group.rvs(row["Dimensionality"])
    Y = Y @ R.transpose() # randomly rotate the data
    for statname, fn in fns_to_run.items():
        try:
            with contextlib.redirect_stderr(None):
                pval, _ = fn(Y, T, X, nrep=nrep)
                pvals.append(pval)
                stat_names.append(statname)
        except:
            pvals.append(float("NaN"))
    with contextlib.redirect_stdout(None):
        balanced_ids = causal_prep(X, T)
    X_bal = X[balanced_ids]; T_bal = T[balanced_ids]; Y_bal = Y[balanced_ids,:]
    for statname, fn in fns_to_run.items():
        try:
            with contextlib.redirect_stderr(None):
                    pval, _ = fn(Y_bal, T_bal, X_bal, nrep=nrep)
                    pvals.append(pval)
                    stat_names.append("Causal {:s}".format(statname))
        except:
            pvals.append(float("NaN"))
    return tuple([row["Setting"], row["#Samples"], row["Dimensionality"], row["Balance"],
                  row["Effect Size"], row["i"], *pvals])

simulations = {
    #"Heteroskedastic" : heteroskedastic_cate,
    #"Function" : diff_fn_cate,
    #"Non-Monotone" : nonmonotonic_sim_cate,
    #"Sigmoidal": sigmoidal_sim_cate,
    "K-Class": kclass_rotation_cate
}
from sims import *

exps = []
counter = 0
for sim in simulations.keys():
    print(sim)
    for p in [plow, phigh]:
        for balance in [blow, bhigh]:
            for eff_sz in np.linspace(0, 1, nbreaks):
                for i in range(nsims):
                    exps.append([sim, nsamp, p, balance, eff_sz, i, counter])
                    counter = counter + 1

sim_exps = pd.DataFrame(exps, columns=["Setting", "#Samples", "Dimensionality", "Balance", "Effect Size", "i", "index"])
print(sim_exps.head(n=10))
print(sim_exps.shape)

client = Client(threads_per_worker=1, n_workers=ncores, silence_logs=logging.ERROR)
print(client)

sim_exps = ddf.from_pandas(sim_exps, npartitions=ncores)
sim_results = sim_exps.apply(lambda x: run_row(x), axis=1, result_type='expand',
                             meta={0: str, 1: int, 2: int, 3: float, 4: float,
                                   5: int, 6: float, 7: float, 8: float, 9: float, 10: float, 11: float,
                                   12: float, 13: float})

sim_results = sim_results.compute(scheduler="multiprocessing")
# io43 = "Linear"
# io44 = "Sigmoidal"
# io46 = "K-Class"
# Out:
# Heteroskedastic
#            Setting  #Samples  Dimensionality  Balance  Effect Size  i  index
# 0  Heteroskedastic         2              10      0.4          0.0  0      0
# 1  Heteroskedastic         2              10      0.4          0.0  1      1
# 2  Heteroskedastic         2              10      0.4          0.0  2      2
# 3  Heteroskedastic         2              10      0.4          0.0  3      3
# 4  Heteroskedastic         2              10      0.4          0.0  4      4
# 5  Heteroskedastic         2              10      0.4          0.0  5      5
# 6  Heteroskedastic         2              10      0.4          0.0  6      6
# 7  Heteroskedastic         2              10      0.4          0.0  7      7
# 8  Heteroskedastic         2              10      0.4          0.0  8      8
# 9  Heteroskedastic         2              10      0.4          0.0  9      9
# (1600, 7)
# <Client: 'tcp://127.0.0.1:50700' processes=50 threads=50, memory=32.00 GiB>
# /Users/eric/.virtualenvs/causal/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/eric/.virtualenvs/causal/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/eric/.virtualenvs/causal/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/eric/.virtualenvs/causal/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/eric/.virtualenvs/causal/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/eric/.virtualenvs/causal/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/eric/.virtualenvs/causal/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/eric/.virtualenvs/causal/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/eric/.virtualenvs/causal/lib/python3.10/site-packages/statsmodels/discrete/discrete_model.py:2299: RuntimeWarning: overflow encountered in exp
#   eXB = np.column_stack((np.ones(len(X)), np.exp(X)))
# /Users/eric/.virtualenvs/causal/lib/python3.10/site-packages/statsmodels/discrete/discrete_model.py:2300: RuntimeWarning: invalid value encountered in divide
#   return eXB/eXB.sum(1)[:,None]
# /Users/eric/.virtualenvs/causal/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/eric/.virtualenvs/causal/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/eric/.virtualenvs/causal/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/eric/.virtualenvs/causal/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/eric/.virtualenvs/causal/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/eric/.virtualenvs/causal/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/eric/.virtualenvs/causal/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/eric/.virtualenvs/causal/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/eric/.virtualenvs/causal/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/eric/.virtualenvs/causal/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/eric/.virtualenvs/causal/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/eric/.virtualenvs/causal/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/eric/.virtualenvs/causal/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/eric/.virtualenvs/causal/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/eric/.virtualenvs/causal/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/eric/.virtualenvs/causal/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Row 800...
# Row 0...
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Cell In[2], line 119
#     113 sim_exps = ddf.from_pandas(sim_exps, npartitions=ncores)
#     114 sim_results = sim_exps.apply(lambda x: run_row(x), axis=1, result_type='expand',
#     115                              meta={0: str, 1: int, 2: int, 3: float, 4: float,
#     116                                    5: int, 6: float, 7: float, 8: float, 9: float, 10: float, 11: float,
#     117                                    12: float, 13: float})
# --> 119 sim_results = sim_results.compute(scheduler="multiprocessing")
#     120 # io43 = "Linear"
#     121 # io44 = "Sigmoidal"
#     122 # io46 = "K-Class"
#
# File ~/.virtualenvs/causal/lib/python3.10/site-packages/dask/base.py:314, in DaskMethodsMixin.compute(self, **kwargs)
#     290 def compute(self, **kwargs):
#     291     """Compute this dask collection
#     292
#     293     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     312     dask.base.compute
#     313     """
# --> 314     (result,) = compute(self, traverse=False, **kwargs)
#     315     return result
#
# File ~/.virtualenvs/causal/lib/python3.10/site-packages/dask/base.py:599, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     596     keys.append(x.__dask_keys__())
#     597     postcomputes.append(x.__dask_postcompute__())
# --> 599 results = schedule(dsk, keys, **kwargs)
#     600 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/.virtualenvs/causal/lib/python3.10/site-packages/dask/multiprocessing.py:233, in get(dsk, keys, num_workers, func_loads, func_dumps, optimize_graph, pool, initializer, chunksize, **kwargs)
#     228 # Note former versions used a multiprocessing Manager to share
#     229 # a Queue between parent and workers, but this is fragile on Windows
#     230 # (issue #1652).
#     231 try:
#     232     # Run
# --> 233     result = get_async(
#     234         pool.submit,
#     235         pool._max_workers,
#     236         dsk3,
#     237         keys,
#     238         get_id=_process_get_id,
#     239         dumps=dumps,
#     240         loads=loads,
#     241         pack_exception=pack_exception,
#     242         raise_exception=reraise,
#     243         chunksize=chunksize,
#     244         **kwargs,
#     245     )
#     246 finally:
#     247     if cleanup:
#
# File ~/.virtualenvs/causal/lib/python3.10/site-packages/dask/local.py:511, in get_async(submit, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, chunksize, **kwargs)
#     509         _execute_task(task, data)  # Re-execute locally
#     510     else:
# --> 511         raise_exception(exc, tb)
#     512 res, worker_id = loads(res_info)
#     513 state["cache"][key] = res
#
# File ~/.virtualenvs/causal/lib/python3.10/site-packages/dask/local.py:318, in reraise(exc, tb)
#     316 def reraise(exc, tb=None):
#     317     if exc.__traceback__ is not tb:
# --> 318         raise exc.with_traceback(tb)
#     319     raise exc
#
# File ~/.virtualenvs/causal/lib/python3.10/site-packages/dask/local.py:224, in execute_task()
#     222 try:
#     223     task, data = loads(task_info)
# --> 224     result = _execute_task(task, data)
#     225     id = get_id()
#     226     result = dumps((result, id))
#
# File ~/.virtualenvs/causal/lib/python3.10/site-packages/dask/core.py:119, in _execute_task()
#     115     func, args = arg[0], arg[1:]
#     116     # Note: Don't assign the subtask results to a variable. numpy detects
#     117     # temporaries by their reference count and can execute certain
#     118     # operations in-place.
# --> 119     return func(*(_execute_task(a, cache) for a in args))
#     120 elif not ishashable(arg):
#     121     return arg
#
# File ~/.virtualenvs/causal/lib/python3.10/site-packages/dask/optimization.py:990, in __call__()
#     988 if not len(args) == len(self.inkeys):
#     989     raise ValueError("Expected %d args, got %d" % (len(self.inkeys), len(args)))
# --> 990 return core.get(self.dsk, self.outkey, dict(zip(self.inkeys, args)))
#
# File ~/.virtualenvs/causal/lib/python3.10/site-packages/dask/core.py:149, in get()
#     147 for key in toposort(dsk):
#     148     task = dsk[key]
# --> 149     result = _execute_task(task, cache)
#     150     cache[key] = result
#     151 result = _execute_task(out, cache)
#
# File ~/.virtualenvs/causal/lib/python3.10/site-packages/dask/core.py:119, in _execute_task()
#     115     func, args = arg[0], arg[1:]
#     116     # Note: Don't assign the subtask results to a variable. numpy detects
#     117     # temporaries by their reference count and can execute certain
#     118     # operations in-place.
# --> 119     return func(*(_execute_task(a, cache) for a in args))
#     120 elif not ishashable(arg):
#     121     return arg
#
# File ~/.virtualenvs/causal/lib/python3.10/site-packages/dask/utils.py:71, in apply()
#      40 """Apply a function given its positional and keyword arguments.
#      41
#      42 Equivalent to ``func(*args, **kwargs)``
#    (...)
#      68 >>> dsk = {'task-name': task}  # adds the task to a low level Dask task graph
#      69 """
#      70 if kwargs:
# ---> 71     return func(*args, **kwargs)
#      72 else:
#      73     return func(*args)
#
# File ~/.virtualenvs/causal/lib/python3.10/site-packages/dask/dataframe/core.py:6784, in apply_and_enforce()
#    6782 func = kwargs.pop("_func")
#    6783 meta = kwargs.pop("_meta")
# -> 6784 df = func(*args, **kwargs)
#    6785 if is_dataframe_like(df) or is_series_like(df) or is_index_like(df):
#    6786     if not len(df):
#
# File ~/.virtualenvs/causal/lib/python3.10/site-packages/dask/utils.py:1103, in __call__()
#    1102 def __call__(self, __obj, *args, **kwargs):
# -> 1103     return getattr(__obj, self.method)(*args, **kwargs)
#
# File ~/.virtualenvs/causal/lib/python3.10/site-packages/pandas/core/frame.py:9565, in apply()
#    9554 from pandas.core.apply import frame_apply
#    9556 op = frame_apply(
#    9557     self,
#    9558     func=func,
#    (...)
#    9563     kwargs=kwargs,
#    9564 )
# -> 9565 return op.apply().__finalize__(self, method="apply")
#
# File ~/.virtualenvs/causal/lib/python3.10/site-packages/pandas/core/apply.py:746, in apply()
#     743 elif self.raw:
#     744     return self.apply_raw()
# --> 746 return self.apply_standard()
#
# File ~/.virtualenvs/causal/lib/python3.10/site-packages/pandas/core/apply.py:873, in apply_standard()
#     872 def apply_standard(self):
# --> 873     results, res_index = self.apply_series_generator()
#     875     # wrap results
#     876     return self.wrap_results(results, res_index)
#
# File ~/.virtualenvs/causal/lib/python3.10/site-packages/pandas/core/apply.py:889, in apply_series_generator()
#     886 with option_context("mode.chained_assignment", None):
#     887     for i, v in enumerate(series_gen):
#     888         # ignore SettingWithCopy here in case the user mutates
# --> 889         results[i] = self.f(v)
#     890         if isinstance(results[i], ABCSeries):
#     891             # If we have a view on v, we need to make a copy because
#     892             #  series_generator will swap out the underlying data
#     893             results[i] = results[i].copy(deep=False)
#
# Cell In[2], line 114, in <lambda>()
#     111 print(client)
#     113 sim_exps = ddf.from_pandas(sim_exps, npartitions=ncores)
# --> 114 sim_results = sim_exps.apply(lambda x: run_row(x), axis=1, result_type='expand',
#     115                              meta={0: str, 1: int, 2: int, 3: float, 4: float,
#     116                                    5: int, 6: float, 7: float, 8: float, 9: float, 10: float, 11: float,
#     117                                    12: float, 13: float})
#     119 sim_results = sim_results.compute(scheduler="multiprocessing")
#     120 # io43 = "Linear"
#     121 # io44 = "Sigmoidal"
#     122 # io46 = "K-Class"
#
# Cell In[2], line 74, in run_row()
#      72         pvals.append(float("NaN"))
#      73 with contextlib.redirect_stdout(None):
# ---> 74     balanced_ids = causal_prep(X, T)
#      75 X_bal = X[balanced_ids]; T_bal = T[balanced_ids]; Y_bal = Y[balanced_ids,:]
#      76 for statname, fn in fns_to_run.items():
#
# File ~/Documents/research/hypo-repos/cdcorr/cdcorr/simulations/sims.py:176, in causal_prep()
#     172 def causal_prep(Xs, Ts, return_props=False):
#     173     # adopted from Lopez 2017 Matching to estimate the causal effect
#     174     # from multiple treatments
#     175     Xs = sm.add_constant(Xs)
# --> 176     m = sm.MNLogit(Ts, Xs)
#     178     fit = m.fit()
#     179     pred = fit.predict(Xs)
#
# File ~/.virtualenvs/causal/lib/python3.10/site-packages/statsmodels/discrete/discrete_model.py:2262, in __init__()
#    2261 def __init__(self, endog, exog, check_rank=True, **kwargs):
# -> 2262     super().__init__(endog, exog, check_rank=check_rank, **kwargs)
#    2264     # Override cov_names since multivariate model
#    2265     yname = self.endog_names
#
# File ~/.virtualenvs/causal/lib/python3.10/site-packages/statsmodels/discrete/discrete_model.py:462, in __init__()
#     459 def __init__(self, endog, exog, check_rank=True, **kwargs):
#     460     # unconditional check, requires no extra kwargs added by subclasses
#     461     self._check_kwargs(kwargs)
# --> 462     super().__init__(endog, exog, check_rank, **kwargs)
#     463     if not issubclass(self.__class__, MultinomialModel):
#     464         if not np.all((self.endog >= 0) & (self.endog <= 1)):
#
# File ~/.virtualenvs/causal/lib/python3.10/site-packages/statsmodels/discrete/discrete_model.py:178, in __init__()
#     176 def __init__(self, endog, exog, check_rank=True, **kwargs):
#     177     self._check_rank = check_rank
# --> 178     super().__init__(endog, exog, **kwargs)
#     179     self.raise_on_perfect_prediction = True
#
# File ~/.virtualenvs/causal/lib/python3.10/site-packages/statsmodels/base/model.py:268, in __init__()
#     266 def __init__(self, endog, exog=None, **kwargs):
#     267     super().__init__(endog, exog, **kwargs)
# --> 268     self.initialize()
#
# File ~/.virtualenvs/causal/lib/python3.10/site-packages/statsmodels/discrete/discrete_model.py:606, in initialize()
#     604 super().initialize()
#     605 # This is also a "whiten" method in other models (eg regression)
# --> 606 self.endog = self.endog.argmax(1)  # turn it into an array of col idx
#     607 self.J = self.wendog.shape[1]
#     608 self.K = self.exog.shape[1]
#
# AxisError: axis 1 is out of bounds for array of dimension 1

# %%
client = Client(threads_per_worker=1, n_workers=ncores, silence_logs=logging.ERROR)
client

# %%
sim_exps = ddf.from_pandas(sim_exps, npartitions=ncores)
sim_results = sim_exps.apply(lambda x: run_row(x), axis=1, result_type='expand',
                             meta={0: str, 1: int, 2: int, 3: float, 4: float,
                                   5: int, 6: float, 7: float, 8: float, 9: float, 10: float, 11: float,
                                   12: float, 13: float})

# %%
sim_results = sim_results.compute(scheduler="multiprocessing")

# %%
sim_results = sim_results.rename(columns={0: "Simulation", 1: "#Samples", 2: "Dimensionality", 3: "Balance",
                                          4: "Effect Size", 5: "i", 6: "cMANOVA", 7: "KernelCDTest", 8: "cDCorr",
                                          9: "DCorr", 10: "Causal cMANOVA", 11: "Causal KernelCDTest", 12: "Causal cDCorr",
                                          13: "Causal DCorr"})
sim_results.to_pickle('./data/sim_results_covarfixed_cate_sig.pkl')
